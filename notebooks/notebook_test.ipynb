# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from racing_coach.core.settings import get_settings
from racing_coach.core.types.telemetry import LapTelemetry
from racing_coach.utils.graphing import make_lap_telemetry_plot

from pathlib import Path

settings = get_settings()

Path.cwd()

# %%
settings.TELEM_SAMPLE

# %%
lap = LapTelemetry.from_parquet(Path.cwd() / ".." / settings.TELEM_SAMPLE)

# %%
fig = make_lap_telemetry_plot(lap)
fig.show()

# %%
from racing_coach.algorithms import braking

events = braking.run(lap)
events

# %%
lap.get_lap_time()

# %%
lap.is_valid()
# Out:
# True
